# %%
# %matplotlib qt
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
sp = np.load("spikes-10.npy")
cal = np.load("cal-10-100.npy")
pre = np.load("pre-10-100-31.npy")

# %%
sp1 = sp[8000:10000]
cal1 = cal[8000:10000]
pre1 = pre[8000:10000]

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(3, 1, 1)
plt.plot(sp1, ".")
plt.subplot(3, 1, 2)
plt.plot(cal1)
plt.subplot(3, 1, 3)
plt.plot(pre1)

# %%
a.shape
# Out:
# (1000000,)
